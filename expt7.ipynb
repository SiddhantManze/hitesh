# %%
import cv2
import numpy as np
import matplotlib.pylab as plt
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img=cv.imread('/content/lena_gray_256.tif')
t=img.mean(axis=2)


sobelx = cv2.Sobel(src=img, ddepth=cv2.CV_64F, dx = 1, dy = 0)
sobely =cv2.Sobel (src =img, ddepth=cv2.CV_64F, dx = 0, dy = 1 )

sobelxy = sobelx+sobely

plt.subplot(2, 2, 1)

plt.imshow(sobelx,cmap='gray')



plt.subplot(2,2, 2)

plt.imshow(sobely, cmap='gray')

plt.subplot(2, 2, 3)

plt.imshow(sobelxy, cmap='gray')



edges = cv2.Canny(image =img, threshold1=100, threshold2 =200)



plt.subplot(2, 2, 4)

plt.imshow(edges, cmap='gray')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-755.0..558.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-689.0..605.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1058.0..1024.0].
