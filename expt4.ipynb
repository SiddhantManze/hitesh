# %%
import cv2

import numpy as np

import matplotlib.pylab as plt

import cv2 as cv

import numpy as np

from matplotlib import pyplot as plt

img=cv.imread('/content/lena_gray_256.tif')
t=img.mean(axis=2)

#m,ning.shape

m,n=t.shape

#Develop Averaging filter(3, 3) mask mask np.ones([3, 3), dtype int)

mask =mask *1/9
img_new= np.zeros([m, n])

for i in range(1, m-1):

           for j in range(1,n-1):

             temp= t[1-1, j-1]*mask[0, 0]+t[i-1, j]*mask[0, 1]+t[1-1, 1]*mask[0, 2]+t[1, j-1]

             img_new[i, j]= temp
img_new = img_new.astype(np.uint8)

cv2.imwrite('blurred.tif', img_new)

plt.subplot(2, 2, 1)
plt.imshow(t,cmap='gray')

plt.subplot(2, 2, 2)
plt.imshow(img_new,cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ef432132b2f7> in <cell line: 0>()
#      24 #Develop Averaging filter(3, 3) mask mask np.ones([3, 3), dtype int)
#      25
# ---> 26 mask =mask *1/9
#      27 img_new= np.zeros([m, n])
#      28
#
# NameError: name 'mask' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
