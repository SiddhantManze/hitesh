# %%
import cv2
import numpy as np
import matplotlib.pylab as plt
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img=cv.imread('/content/lena_gray_256.tif')
kernel =np.ones((5, 5), np.uint8)

img_erosion = cv2.erode(img, kernel, iterations=1)

img_dilation = cv2.dilate(img, kernel, iterations=1)

img_opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

img_closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.subplot(2, 2, 1)

plt.imshow(img_erosion,cmap='gray')

plt.subplot(2, 2, 2)

plt.imshow(img_dilation,cmap='gray')

plt.subplot(2, 2, 3)

plt.imshow(img_opening,cmap='gray')

plt.subplot(2, 2, 4)

plt.imshow(img_closing,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-351e2d647633> in <cell line: 0>()
#       8 kernel =np.ones((5, 5), np.uint8)
#       9
# ---> 10 img_erosion = cv2.erode(img, kernel, iterations=1)
#      11
#      12 img_dilation = cv2.dilate(img, kernel, iterations=1)
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/morph.dispatch.cpp:1010: error: (-215:Assertion failed) !src.empty() in function 'erode'
